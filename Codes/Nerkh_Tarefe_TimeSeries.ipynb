# %%
import pandas as pd
import numpy as np
import os
import openpyxl
import xlrd

# %%
# Set the working directory
os.chdir("C:\TradeGroup")
my_wd = os.getcwd()
new_directory = my_wd

def create_folder(folder_path):
    if not os.path.exists(f'{new_directory}/{folder_path}'):
        os.makedirs(f'{new_directory}/{folder_path}')
    else:
        print(f'Already Exists')

create_folder('Data/Indices')
# Out:
# Already Exists

# %%
sheet_names = [75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87]

nerkh_tarefe_list = []

for i, sheet_name in enumerate(sheet_names, start=1):
    df_name = f"Nerkh_Tarefe_13{sheet_name}"
    
    # Load the sheet into a dataframe
    df = pd.read_excel("C:/TradeGroup/Reports/Hoghough_Voroudi_80s_Renamed.xlsx", sheet_name=str(sheet_name))
    
    # Rename the dataframe
    df.name = df_name
    
    # Append the dataframe to the list
    nerkh_tarefe_list.append(df)

# %%
nerkh_tarefe_list
# Out:
# [      Year   Tcode                                              Tdesc  \
#  0     1375   10511           مرغ وخروس چازنوع خانگي بوزن 185گرم وكمتر
#  1     1375   10519  گرم وكمتر اردك چغازچبوقلمون ومرغ شاخدارچزنده چ...
#  2     1375   10600  حيوانات زنده چغيرازمواردزير:الف -ماهيهاوقشردار...
#  3     1375   20220  -گوشت حيوانات ازنوع گاويخ زده چبصورت قطعات باا...
#  4     1375   20230   -گوشت حيوانات ازنوع گاوچيخ زده چبصورت بي استخوان
#  ...    ...     ...                                                ...
#  2965  1375  961380  -فندك هاغيرازانهائيكه مشمول شماره هاي 9613/10و...
#  2966  1375  961390  -اجزاأوقطعات مربوطبه كالاي مشمول شماره 9613/10...
#  2967  1375  961590  -سنجاق زلف چسنجاق فردهنده چفرزن مو(bigoudi)وهم...
#  2968  1375  961700  فلاسك وسايرظروف عايق حرارت بامحفظه چكه عايق اج...
#  2969  1375  961800  مانكن خياطي وسايرادمك هاي چوبي چادمكهاي متحرك ...
#
#          Weight         Rials       Dollars       Hsum       Hperc
# ...

# %%
Nerkh_List
# Out:
# [         Tcode       Weight         Rials       Dollars  \
#  0      1012910     66500.00  1.087538e+11  3.427000e+06
#  1      1022110    569447.00  1.027772e+11  3.362400e+06
#  2      1022120   6030138.00  3.369980e+11  1.083579e+07
#  3      1022900  18027117.00  1.018404e+12  3.254929e+07
#  4      1041010       900.00  4.434705e+08  1.400463e+04
#  ...        ...          ...           ...           ...
#  5898  98871181     59876.79  3.132857e+10  9.678549e+05
#  5899  98871182     29679.75  6.845494e+09  2.133151e+05
#  5900  98871183     15044.61  2.305398e+09  7.111913e+04
#  5901  98871191    136299.00  3.125132e+10  9.738208e+05
#  5902  98871195    209276.00  3.900686e+10  1.206240e+06
#
#        حقوق ورودی 041 (ریال)  سایر 042 (ریال)  043(ریال)  \
#  0              3.113956e+10      150165322.0        0.0
#  1              5.145761e+09       27728803.0        0.0
#  2              1.653329e+10      108979635.0        0.0
# ...

# %%
Nerkh_Tarefe_1395 = pd.read_excel(f'C:/TradeGroup/Reports/Nerkh_Tarefe_Part2_Renamed.xlsx',sheet_name="1395")
Nerkh_Tarefe_1396 = pd.read_excel(f'C:/TradeGroup/Reports/Nerkh_Tarefe_Part2_Renamed.xlsx',sheet_name="1396")
Nerkh_Tarefe_1397 = pd.read_excel(f'C:/TradeGroup/Reports/Nerkh_Tarefe_Renamed.xlsx',sheet_name="1397")
Nerkh_Tarefe_1398 = pd.read_excel(f'C:/TradeGroup/Reports/Nerkh_Tarefe_Renamed.xlsx',sheet_name="1398")
Nerkh_Tarefe_1399 = pd.read_excel(f'C:/TradeGroup/Reports/Nerkh_Tarefe_Renamed.xlsx',sheet_name="1399")
Nerkh_Tarefe_1400 = pd.read_excel(f'C:/TradeGroup/Reports/Nerkh_Tarefe_Renamed.xlsx',sheet_name="1400")
Nerkh_Tarefe_1401 = pd.read_excel(f'C:/TradeGroup/Reports/Nerkh_Tarefe_Renamed.xlsx',sheet_name="1401")
Nerkh_Tarefe_1402 = pd.read_excel(f'C:/TradeGroup/Reports/Nerkh_Tarefe_Part2_Renamed.xlsx',sheet_name="1402")
Nerkh_Tarefe_1403 = pd.read_excel(f'C:/TradeGroup/Reports/Nerkh_Tarefe_Part2_Renamed.xlsx',sheet_name="1403_03")



Nerkh_List = [Nerkh_Tarefe_1395,Nerkh_Tarefe_1396,Nerkh_Tarefe_1397,Nerkh_Tarefe_1398,Nerkh_Tarefe_1399,Nerkh_Tarefe_1400,
              Nerkh_Tarefe_1401,Nerkh_Tarefe_1402,Nerkh_Tarefe_1403]

Nerkh_Names = ['1375', '1376', '1377', '1378', '1379', '1380', '1381', '1382', '1383', '1384', '1385', '1386', '1387',
               "1395","1396","1397","1398","1399","1400","1401","1402","1403-3"]




Nerkh_List =nerkh_tarefe_list + Nerkh_List

# %%
result_df = pd.DataFrame(columns=['Year', 'Hoghough_Voroudi'])
for Nerkhname, Nerkh in zip(Nerkh_Names,Nerkh_List):
    HPercentage = 100*Nerkh['Hsum'].sum()/Nerkh['Rials'].sum()
    temp_df = pd.DataFrame([[Nerkhname, HPercentage]], columns=['Year', 'Hoghough_Voroudi'])
    result_df = pd.concat([result_df,temp_df])
# Out:
# C:\Users\msbirjandi\AppData\Local\Temp\ipykernel_8772\1257736761.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result_df = pd.concat([result_df,temp_df])

# %%
result_df.to_excel(f'C:/TradeGroup/Reports/Hoghough_Voroudi_Timeseries.xlsx',index=False)
