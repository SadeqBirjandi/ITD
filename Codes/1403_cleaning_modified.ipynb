# %%
import pandas as pd
import numpy as np
import openpyxl
import os
import pathlib

# %%
new_directory = "C:\TradeGroup"
os.chdir(new_directory)
my_wd = new_directory

# %%
def create_folder(folder_path):
    if not os.path.exists(f'{new_directory}/{folder_path}'):
        os.makedirs(f'{new_directory}/{folder_path}')
    else:
        print(f'Already Exists')

# %%
Import_08 = pd.read_excel(f'C:/TradeGroup/Data/RawData/Imp140308first.xlsx')
Import_08.columns=['Year','Custom','Country','Tcode','Tdesc','Weight_08','Rials_08','Dollars_08']
Tcode_Tdesc = Import_08[['Tcode','Tdesc']]
Tcode_Tdesc = Tcode_Tdesc.drop_duplicates(subset='Tcode', keep='first')

Import_08_new = Import_08[['Year','Custom','Country','Tcode','Weight_08','Rials_08','Dollars_08']]
Import_08_new = Import_08_new.dropna(subset='Country')
Import_08_new['Year']= 1403


Import_07 = pd.read_excel(f'C:/TradeGroup/Data/RawData/Imp140307first.xlsx')
Import_07.columns=['Year','Custom','Country','Tcode','Tdesc','Weight_07','Rials_07','Dollars_07']
Import_07_new = Import_07[['Year','Custom','Country','Tcode','Weight_07','Rials_07','Dollars_07']]
Import_07_new = Import_07_new.dropna(subset='Country')
Import_07_new['Year']= 1403

Import_0807 = Import_08_new.merge(Import_07_new,on=['Year','Custom','Country','Tcode'], how='outer')

Import_0807 = Import_0807.fillna(0)

Import_0807['Weight_08_Only']= Import_0807['Weight_08'] - Import_0807['Weight_07']

Import_0807['Rials_08_Only']= Import_0807['Rials_08'] - Import_0807['Rials_07']

Import_0807['Dollars_08_Only']= Import_0807['Dollars_08'] - Import_0807['Dollars_07']

Import_08_only = Import_0807[['Year','Custom','Country','Tcode','Weight_08_Only','Rials_08_Only','Dollars_08_Only']]

Import_08_only = Import_08_only[(Import_08_only['Dollars_08_Only']!=0) & (Import_08_only['Weight_08_Only']!=0) & (Import_08_only['Rials_08_Only']!=0)]

Import_08_only['Month']= 8





#Import_07 = pd.read_excel(f'C:/TradeGroup/Data/RawData/Imp140307first.xlsx')
Import_07.columns=['Year','Custom','Country','Tcode','Tdesc','Weight_07','Rials_07','Dollars_07']
Tcode_Tdesc = Import_07[['Tcode','Tdesc']]
Tcode_Tdesc = Tcode_Tdesc.drop_duplicates(subset='Tcode', keep='first')

Import_07_new = Import_07[['Year','Custom','Country','Tcode','Weight_07','Rials_07','Dollars_07']]
Import_07_new = Import_07_new.dropna(subset='Country')
Import_07_new['Year']= 1403


Import_06 = pd.read_excel(f'C:/TradeGroup/Data/RawData/Imp140306first.xlsx')
Import_06.columns=['Year','Custom','Country','Tcode','Tdesc','Weight_06','Rials_06','Dollars_06']
Import_06_new = Import_06[['Year','Custom','Country','Tcode','Weight_06','Rials_06','Dollars_06']]
Import_06_new = Import_06_new.dropna(subset='Country')
Import_06_new['Year']= 1403

Import_0706 = Import_07_new.merge(Import_06_new,on=['Year','Custom','Country','Tcode'], how='outer')

Import_0706 = Import_0706.fillna(0)

Import_0706['Weight_07_Only']= Import_0706['Weight_07'] - Import_0706['Weight_06']

Import_0706['Rials_07_Only']= Import_0706['Rials_07'] - Import_0706['Rials_06']

Import_0706['Dollars_07_Only']= Import_0706['Dollars_07'] - Import_0706['Dollars_06']

Import_07_only = Import_0706[['Year','Custom','Country','Tcode','Weight_07_Only','Rials_07_Only','Dollars_07_Only']]

Import_07_only = Import_07_only[(Import_07_only['Dollars_07_Only']!=0) & (Import_07_only['Weight_07_Only']!=0) & (Import_07_only['Rials_07_Only']!=0)]

Import_07_only['Month']= 7



#Import_06 = pd.read_excel(f'C:/TradeGroup/Data/RawData/Imp140306first.xlsx')
Import_06.columns=['Year','Custom','Country','Tcode','Tdesc','Weight_06','Rials_06','Dollars_06']
Tcode_Tdesc = Import_06[['Tcode','Tdesc']]
Tcode_Tdesc = Tcode_Tdesc.drop_duplicates(subset='Tcode', keep='first')

Import_06_new = Import_06[['Year','Custom','Country','Tcode','Weight_06','Rials_06','Dollars_06']]
Import_06_new = Import_06_new.dropna(subset='Country')
Import_06_new['Year']= 1403


Import_05 = pd.read_excel(f'C:/TradeGroup/Data/RawData/Imp140305first.xlsx')
Import_05.columns=['Year','Custom','Country','Tcode','Tdesc','Weight_05','Rials_05','Dollars_05']
Import_05_new = Import_05[['Year','Custom','Country','Tcode','Weight_05','Rials_05','Dollars_05']]
Import_05_new = Import_05_new.dropna(subset='Country')
Import_05_new['Year']= 1403

Import_0605 = Import_06_new.merge(Import_05_new,on=['Year','Custom','Country','Tcode'], how='outer')

Import_0605 = Import_0605.fillna(0)

Import_0605['Weight_06_Only']= Import_0605['Weight_06'] - Import_0605['Weight_05']

Import_0605['Rials_06_Only']= Import_0605['Rials_06'] - Import_0605['Rials_05']

Import_0605['Dollars_06_Only']= Import_0605['Dollars_06'] - Import_0605['Dollars_05']

Import_06_only = Import_0605[['Year','Custom','Country','Tcode','Weight_06_Only','Rials_06_Only','Dollars_06_Only']]

Import_06_only = Import_06_only[(Import_06_only['Dollars_06_Only']!=0) & (Import_06_only['Weight_06_Only']!=0) & (Import_06_only['Rials_06_Only']!=0)]

Import_06_only['Month']= 6






#Import_05 = pd.read_excel(f'C:/TradeGroup/Data/RawData/Imp140305first.xlsx')
Import_05.columns=['Year','Custom','Country','Tcode','Tdesc','Weight_05','Rials_05','Dollars_05']
Tcode_Tdesc = Import_05[['Tcode','Tdesc']]
Tcode_Tdesc = Tcode_Tdesc.drop_duplicates(subset='Tcode', keep='first')

Import_05_new = Import_05[['Year','Custom','Country','Tcode','Weight_05','Rials_05','Dollars_05']]
Import_05_new = Import_05_new.dropna(subset='Country')
Import_05_new['Year']= 1403


Import_04 = pd.read_excel(f'C:/TradeGroup/Data/RawData/Imp140304first.xlsx')
Import_04.columns=['Year','Custom','Country','Tcode','Tdesc','Weight_04','Rials_04','Dollars_04']
Import_04_new = Import_04[['Year','Custom','Country','Tcode','Weight_04','Rials_04','Dollars_04']]
Import_04_new = Import_04_new.dropna(subset='Country')
Import_04_new['Year']= 1403

Import_0504 = Import_05_new.merge(Import_04_new,on=['Year','Custom','Country','Tcode'], how='outer')

Import_0504 = Import_0504.fillna(0)

Import_0504['Weight_05_Only']= Import_0504['Weight_05'] - Import_0504['Weight_04']

Import_0504['Rials_05_Only']= Import_0504['Rials_05'] - Import_0504['Rials_04']

Import_0504['Dollars_05_Only']= Import_0504['Dollars_05'] - Import_0504['Dollars_04']

Import_05_only = Import_0504[['Year','Custom','Country','Tcode','Weight_05_Only','Rials_05_Only','Dollars_05_Only']]

Import_05_only = Import_05_only[(Import_05_only['Dollars_05_Only']!=0) & (Import_05_only['Weight_05_Only']!=0) & (Import_05_only['Rials_05_Only']!=0)]

Import_05_only['Month']= 5







#Import_04 = pd.read_excel(f'C:/TradeGroup/Data/RawData/Imp140304first.xlsx')
Import_04.columns=['Year','Custom','Country','Tcode','Tdesc','Weight_04','Rials_04','Dollars_04']
Tcode_Tdesc = Import_04[['Tcode','Tdesc']]
Tcode_Tdesc = Tcode_Tdesc.drop_duplicates(subset='Tcode', keep='first')

Import_04_new = Import_04[['Year','Custom','Country','Tcode','Weight_04','Rials_04','Dollars_04']]
Import_04_new = Import_04_new.dropna(subset='Country')
Import_04_new['Year']= 1403


Import_03 = pd.read_excel(f'C:/TradeGroup/Data/RawData/Imp140303first.xlsx')
Import_03.columns=['Year','Custom','Country','Tcode','Tdesc','Weight_03','Rials_03','Dollars_03']
Import_03_new = Import_03[['Year','Custom','Country','Tcode','Weight_03','Rials_03','Dollars_03']]
Import_03_new = Import_03_new.dropna(subset='Country')
Import_03_new['Year']= 1403

Import_0403 = Import_04_new.merge(Import_03_new,on=['Year','Custom','Country','Tcode'], how='outer')

Import_0403 = Import_0403.fillna(0)

Import_0403['Weight_04_Only']= Import_0403['Weight_04'] - Import_0403['Weight_03']

Import_0403['Rials_04_Only']= Import_0403['Rials_04'] - Import_0403['Rials_03']

Import_0403['Dollars_04_Only']= Import_0403['Dollars_04'] - Import_0403['Dollars_03']

Import_04_only = Import_0403[['Year','Custom','Country','Tcode','Weight_04_Only','Rials_04_Only','Dollars_04_Only']]

Import_04_only = Import_04_only[(Import_04_only['Dollars_04_Only']!=0) & (Import_04_only['Weight_04_Only']!=0) & (Import_04_only['Rials_04_Only']!=0)]

Import_04_only['Month']= 4


Import_02 = pd.read_excel(f'C:/TradeGroup/Data/RawData/Imp140302first.xlsx')
Import_02.columns=['Year','Custom','Country','Tcode','Tdesc','Weight_02','Rials_02','Dollars_02']
Import_02_new = Import_02[['Year','Custom','Country','Tcode','Weight_02','Rials_02','Dollars_02']]
Import_02_new = Import_02_new.dropna(subset='Country')
Import_02_new['Year']= 1403



Import_0302 = Import_03_new.merge(Import_02_new,on=['Year','Custom','Country','Tcode'], how='outer')

Import_0302 = Import_0302.fillna(0)

Import_0302['Weight_03_Only']= Import_0302['Weight_03'] - Import_0302['Weight_02']

Import_0302['Rials_03_Only']= Import_0302['Rials_03'] - Import_0302['Rials_02']

Import_0302['Dollars_03_Only']= Import_0302['Dollars_03'] - Import_0302['Dollars_02']

Import_03_only = Import_0302[['Year','Custom','Country','Tcode','Weight_03_Only','Rials_03_Only','Dollars_03_Only']]


Import_03_only = Import_03_only[(Import_03_only['Dollars_03_Only']!=0) & (Import_03_only['Weight_03_Only']!=0) & (Import_03_only['Rials_03_Only']!=0)]

Import_03_only['Month']= 3



Import_01 = pd.read_excel(f'C:/TradeGroup/Data/RawData/Imp140301first.xlsx')
Import_01.columns=['Year','Month','Custom','Country','Tcode','Tdesc','Weight_01','Rials_01','Dollars_01']
Import_01_new = Import_01[['Year','Custom','Country','Tcode','Weight_01','Rials_01','Dollars_01']]
Import_01_new = Import_01_new.dropna(subset='Country')
Import_01_new['Tcode']= Import_01_new['Tcode'].astype('int')
Import_01_new['Year']= 1403


Import_0201 = Import_02_new.merge(Import_01_new,on=['Year','Custom','Country','Tcode'], how='outer')

Import_0201 = Import_0201.fillna(0)

Import_0201['Weight_02_Only']= Import_0201['Weight_02'] - Import_0201['Weight_01']

Import_0201['Rials_02_Only']= Import_0201['Rials_02'] - Import_0201['Rials_01']

Import_0201['Dollars_02_Only']= Import_0201['Dollars_02'] - Import_0201['Dollars_01']

Import_02_only = Import_0201[['Year','Custom','Country','Tcode','Weight_02_Only','Rials_02_Only','Dollars_02_Only']]


Import_02_only = Import_02_only[(Import_02_only['Dollars_02_Only']!=0) & (Import_02_only['Weight_02_Only']!=0) & (Import_02_only['Rials_02_Only']!=0)]

Import_02_only['Month']= 2

Import_01_only = Import_01_new

Import_01_only['Month']= 1



Import_08_only.columns = ['Year','Custom','Country','Tcode','Weight','Rials','Dollars','Month']
Import_07_only.columns = ['Year','Custom','Country','Tcode','Weight','Rials','Dollars','Month']
Import_06_only.columns = ['Year','Custom','Country','Tcode','Weight','Rials','Dollars','Month']
Import_05_only.columns = ['Year','Custom','Country','Tcode','Weight','Rials','Dollars','Month']
Import_04_only.columns = ['Year','Custom','Country','Tcode','Weight','Rials','Dollars','Month']
Import_03_only.columns = ['Year','Custom','Country','Tcode','Weight','Rials','Dollars','Month']
Import_02_only.columns = ['Year','Custom','Country','Tcode','Weight','Rials','Dollars','Month']
Import_01_only.columns = ['Year','Custom','Country','Tcode','Weight','Rials','Dollars','Month']


Imports_Tot = pd.concat([Import_08_only,Import_07_only,Import_06_only,Import_05_only,Import_04_only,Import_03_only,Import_02_only,Import_01_only])


Imports_Tot = Imports_Tot.merge(Tcode_Tdesc,on='Tcode',how='left')

# %%
Imports_Tot
# Out:
#         Year                      Custom            Country       Tcode  \
# 0       1403                      آستارا              آلمان  84571000.0
# 1       1403                      آستارا  امارات متحده عربي   2011090.0
# 2       1403                      آستارا  امارات متحده عربي   2041000.0
# 3       1403                      آستارا  امارات متحده عربي   7132030.0
# 4       1403                      آستارا  امارات متحده عربي   7134090.0
# ...      ...                         ...                ...         ...
# 121485  1403  منطقه ويژه اقتصادي سلفچگان              ترکيه  76061290.0
# 121486  1403  منطقه ويژه اقتصادي سلفچگان              ترکيه  84145920.0
# 121487  1403  منطقه ويژه اقتصادي سلفچگان              ترکيه  84248910.0
# 121488  1403  منطقه ويژه اقتصادي سلفچگان              ترکيه  90318050.0
# 121489  1403  منطقه ويژه اقتصادي سلفچگان             تايوان  35069190.0
#
#            Weight         Rials    Dollars  Month  \
# 0          3200.0  2.101916e+09     7375.0      8
# ...

# %%
Export_08 = pd.read_excel(f'C:/TradeGroup/Data/RawData/Exp140308first.xlsx')
Export_08.columns=['Year','Custom','Country','Tcode','Tdesc','Weight_08','Rials_08','Dollars_08']
Tcode_Tdesc = Export_08[['Tcode','Tdesc']]
Tcode_Tdesc = Tcode_Tdesc.drop_duplicates(subset='Tcode', keep='first')

Export_08_new = Export_08[['Year','Custom','Country','Tcode','Weight_08','Rials_08','Dollars_08']]
Export_08_new = Export_08_new.dropna(subset='Country')
Export_08_new['Year']= 1403


Export_07 = pd.read_excel(f'C:/TradeGroup/Data/RawData/Exp140307first.xlsx')
Export_07.columns=['Year','Custom','Country','Tcode','Tdesc','Weight_07','Rials_07','Dollars_07']
Export_07_new = Export_07[['Year','Custom','Country','Tcode','Weight_07','Rials_07','Dollars_07']]
Export_07_new = Export_07_new.dropna(subset='Country')
Export_07_new['Year']= 1403

Export_0807 = Export_08_new.merge(Export_07_new,on=['Year','Custom','Country','Tcode'], how='outer')

Export_0807 = Export_0807.fillna(0)

Export_0807['Weight_08_Only']= Export_0807['Weight_08'] - Export_0807['Weight_07']

Export_0807['Rials_08_Only']= Export_0807['Rials_08'] - Export_0807['Rials_07']

Export_0807['Dollars_08_Only']= Export_0807['Dollars_08'] - Export_0807['Dollars_07']

Export_08_only = Export_0807[['Year','Custom','Country','Tcode','Weight_08_Only','Rials_08_Only','Dollars_08_Only']]

Export_08_only = Export_08_only[(Export_08_only['Dollars_08_Only']!=0) & (Export_08_only['Weight_08_Only']!=0) & (Export_08_only['Rials_08_Only']!=0)]

Export_08_only['Month']= 8








#Export_07 = pd.read_excel(f'C:/TradeGroup/Data/RawData/Exp140307first.xlsx')
Export_07.columns=['Year','Custom','Country','Tcode','Tdesc','Weight_07','Rials_07','Dollars_07']
Tcode_Tdesc = Export_07[['Tcode','Tdesc']]
Tcode_Tdesc = Tcode_Tdesc.drop_duplicates(subset='Tcode', keep='first')

Export_07_new = Export_07[['Year','Custom','Country','Tcode','Weight_07','Rials_07','Dollars_07']]
Export_07_new = Export_07_new.dropna(subset='Country')
Export_07_new['Year']= 1403


Export_06 = pd.read_excel(f'C:/TradeGroup/Data/RawData/Exp140306first.xlsx')
Export_06.columns=['Year','Custom','Country','Tcode','Tdesc','Weight_06','Rials_06','Dollars_06']
Export_06_new = Export_06[['Year','Custom','Country','Tcode','Weight_06','Rials_06','Dollars_06']]
Export_06_new = Export_06_new.dropna(subset='Country')
Export_06_new['Year']= 1403

Export_0706 = Export_07_new.merge(Export_06_new,on=['Year','Custom','Country','Tcode'], how='outer')

Export_0706 = Export_0706.fillna(0)

Export_0706['Weight_07_Only']= Export_0706['Weight_07'] - Export_0706['Weight_06']

Export_0706['Rials_07_Only']= Export_0706['Rials_07'] - Export_0706['Rials_06']

Export_0706['Dollars_07_Only']= Export_0706['Dollars_07'] - Export_0706['Dollars_06']

Export_07_only = Export_0706[['Year','Custom','Country','Tcode','Weight_07_Only','Rials_07_Only','Dollars_07_Only']]

Export_07_only = Export_07_only[(Export_07_only['Dollars_07_Only']!=0) & (Export_07_only['Weight_07_Only']!=0) & (Export_07_only['Rials_07_Only']!=0)]

Export_07_only['Month']= 7






#Export_06 = pd.read_excel(f'C:/TradeGroup/Data/RawData/Exp140306first.xlsx')
Export_06.columns=['Year','Custom','Country','Tcode','Tdesc','Weight_06','Rials_06','Dollars_06']
Tcode_Tdesc = Export_06[['Tcode','Tdesc']]
Tcode_Tdesc = Tcode_Tdesc.drop_duplicates(subset='Tcode', keep='first')

Export_06_new = Export_06[['Year','Custom','Country','Tcode','Weight_06','Rials_06','Dollars_06']]
Export_06_new = Export_06_new.dropna(subset='Country')
Export_06_new['Year']= 1403


Export_05 = pd.read_excel(f'C:/TradeGroup/Data/RawData/Exp140305first.xlsx')
Export_05.columns=['Year','Custom','Country','Tcode','Tdesc','Weight_05','Rials_05','Dollars_05']
Export_05_new = Export_05[['Year','Custom','Country','Tcode','Weight_05','Rials_05','Dollars_05']]
Export_05_new = Export_05_new.dropna(subset='Country')
Export_05_new['Year']= 1403

Export_0605 = Export_06_new.merge(Export_05_new,on=['Year','Custom','Country','Tcode'], how='outer')

Export_0605 = Export_0605.fillna(0)

Export_0605['Weight_06_Only']= Export_0605['Weight_06'] - Export_0605['Weight_05']

Export_0605['Rials_06_Only']= Export_0605['Rials_06'] - Export_0605['Rials_05']

Export_0605['Dollars_06_Only']= Export_0605['Dollars_06'] - Export_0605['Dollars_05']

Export_06_only = Export_0605[['Year','Custom','Country','Tcode','Weight_06_Only','Rials_06_Only','Dollars_06_Only']]

Export_06_only = Export_06_only[(Export_06_only['Dollars_06_Only']!=0) & (Export_06_only['Weight_06_Only']!=0) & (Export_06_only['Rials_06_Only']!=0)]

Export_06_only['Month']= 6





#Export_05 = pd.read_excel(f'C:/TradeGroup/Data/RawData/Exp140305first.xlsx')
Export_05.columns=['Year','Custom','Country','Tcode','Tdesc','Weight_05','Rials_05','Dollars_05']
Tcode_Tdesc = Export_05[['Tcode','Tdesc']]
Tcode_Tdesc = Tcode_Tdesc.drop_duplicates(subset='Tcode', keep='first')

Export_05_new = Export_05[['Year','Custom','Country','Tcode','Weight_05','Rials_05','Dollars_05']]
Export_05_new = Export_05_new.dropna(subset='Country')
Export_05_new['Year']= 1403


Export_04 = pd.read_excel(f'C:/TradeGroup/Data/RawData/Exp140304first.xlsx')
Export_04.columns=['Year','Custom','Country','Tcode','Tdesc','Weight_04','Rials_04','Dollars_04']
Export_04_new = Export_04[['Year','Custom','Country','Tcode','Weight_04','Rials_04','Dollars_04']]
Export_04_new = Export_04_new.dropna(subset='Country')
Export_04_new['Year']= 1403

Export_0504 = Export_05_new.merge(Export_04_new,on=['Year','Custom','Country','Tcode'], how='outer')

Export_0504 = Export_0504.fillna(0)

Export_0504['Weight_05_Only']= Export_0504['Weight_05'] - Export_0504['Weight_04']

Export_0504['Rials_05_Only']= Export_0504['Rials_05'] - Export_0504['Rials_04']

Export_0504['Dollars_05_Only']= Export_0504['Dollars_05'] - Export_0504['Dollars_04']

Export_05_only = Export_0504[['Year','Custom','Country','Tcode','Weight_05_Only','Rials_05_Only','Dollars_05_Only']]

Export_05_only = Export_05_only[(Export_05_only['Dollars_05_Only']!=0) & (Export_05_only['Weight_05_Only']!=0) & (Export_05_only['Rials_05_Only']!=0)]

Export_05_only['Month']= 5





Export_04 = pd.read_excel(f'C:/TradeGroup/Data/RawData/Exp140304first.xlsx')
Export_04.columns=['Year','Custom','Country','Tcode','Tdesc','Weight_04','Rials_04','Dollars_04']
Tcode_Tdesc = Export_04[['Tcode','Tdesc']]
Tcode_Tdesc = Tcode_Tdesc.drop_duplicates(subset='Tcode', keep='first')

Export_04_new = Export_04[['Year','Custom','Country','Tcode','Weight_04','Rials_04','Dollars_04']]
Export_04_new = Export_04_new.dropna(subset='Country')
Export_04_new['Year']= 1403


Export_03 = pd.read_excel(f'C:/TradeGroup/Data/RawData/Exp140303first.xlsx')
Export_03.columns=['Year','Custom','Country','Tcode','Tdesc','Weight_03','Rials_03','Dollars_03']
Export_03_new = Export_03[['Year','Custom','Country','Tcode','Weight_03','Rials_03','Dollars_03']]
Export_03_new = Export_03_new.dropna(subset='Country')
Export_03_new['Year']= 1403

Export_0403 = Export_04_new.merge(Export_03_new,on=['Year','Custom','Country','Tcode'], how='outer')

Export_0403 = Export_0403.fillna(0)

Export_0403['Weight_04_Only']= Export_0403['Weight_04'] - Export_0403['Weight_03']

Export_0403['Rials_04_Only']= Export_0403['Rials_04'] - Export_0403['Rials_03']

Export_0403['Dollars_04_Only']= Export_0403['Dollars_04'] - Export_0403['Dollars_03']

Export_04_only = Export_0403[['Year','Custom','Country','Tcode','Weight_04_Only','Rials_04_Only','Dollars_04_Only']]

Export_04_only = Export_04_only[(Export_04_only['Dollars_04_Only']!=0) & (Export_04_only['Weight_04_Only']!=0) & (Export_04_only['Rials_04_Only']!=0)]

Export_04_only['Month']= 4


Export_02 = pd.read_excel(f'C:/TradeGroup/Data/RawData/Exp140302first.xlsx')
Export_02.columns=['Year','Custom','Country','Tcode','Tdesc','Weight_02','Rials_02','Dollars_02']
Export_02_new = Export_02[['Year','Custom','Country','Tcode','Weight_02','Rials_02','Dollars_02']]
Export_02_new = Export_02_new.dropna(subset='Country')
Export_02_new['Year']= 1403



Export_0302 = Export_03_new.merge(Export_02_new,on=['Year','Custom','Country','Tcode'], how='outer')

Export_0302 = Export_0302.fillna(0)

Export_0302['Weight_03_Only']= Export_0302['Weight_03'] - Export_0302['Weight_02']

Export_0302['Rials_03_Only']= Export_0302['Rials_03'] - Export_0302['Rials_02']

Export_0302['Dollars_03_Only']= Export_0302['Dollars_03'] - Export_0302['Dollars_02']

Export_03_only = Export_0302[['Year','Custom','Country','Tcode','Weight_03_Only','Rials_03_Only','Dollars_03_Only']]


Export_03_only = Export_03_only[(Export_03_only['Dollars_03_Only']!=0) & (Export_03_only['Weight_03_Only']!=0) & (Export_03_only['Rials_03_Only']!=0)]

Export_03_only['Month']= 3



Export_01 = pd.read_excel(f'C:/TradeGroup/Data/RawData/Exp140301first.xlsx')
Export_01.columns=['Year','Month','Custom','Country','Tcode','Tdesc','Weight_01','Rials_01','Dollars_01']
Export_01_new = Export_01[['Year','Custom','Country','Tcode','Weight_01','Rials_01','Dollars_01']]
Export_01_new = Export_01_new.dropna(subset='Country')
Export_01_new['Tcode']= Export_01_new['Tcode'].astype('int')
Export_01_new['Year']= 1403


Export_0201 = Export_02_new.merge(Export_01_new,on=['Year','Custom','Country','Tcode'], how='outer')

Export_0201 = Export_0201.fillna(0)

Export_0201['Weight_02_Only']= Export_0201['Weight_02'] - Export_0201['Weight_01']

Export_0201['Rials_02_Only']= Export_0201['Rials_02'] - Export_0201['Rials_01']

Export_0201['Dollars_02_Only']= Export_0201['Dollars_02'] - Export_0201['Dollars_01']

Export_02_only = Export_0201[['Year','Custom','Country','Tcode','Weight_02_Only','Rials_02_Only','Dollars_02_Only']]


Export_02_only = Export_02_only[(Export_02_only['Dollars_02_Only']!=0) & (Export_02_only['Weight_02_Only']!=0) & (Export_02_only['Rials_02_Only']!=0)]

Export_02_only['Month']= 2

Export_01_only = Export_01_new

Export_01_only['Month']= 1


Export_08_only.columns = ['Year','Custom','Country','Tcode','Weight','Rials','Dollars','Month']
Export_07_only.columns = ['Year','Custom','Country','Tcode','Weight','Rials','Dollars','Month']
Export_06_only.columns = ['Year','Custom','Country','Tcode','Weight','Rials','Dollars','Month']
Export_05_only.columns = ['Year','Custom','Country','Tcode','Weight','Rials','Dollars','Month']
Export_04_only.columns = ['Year','Custom','Country','Tcode','Weight','Rials','Dollars','Month']
Export_03_only.columns = ['Year','Custom','Country','Tcode','Weight','Rials','Dollars','Month']
Export_02_only.columns = ['Year','Custom','Country','Tcode','Weight','Rials','Dollars','Month']
Export_01_only.columns = ['Year','Custom','Country','Tcode','Weight','Rials','Dollars','Month']


Exports_Tot = pd.concat([Export_08_only,Export_07_only,Export_06_only,Export_05_only,Export_04_only,Export_03_only,Export_02_only,Export_01_only])


Exports_Tot = Exports_Tot.merge(Tcode_Tdesc,on='Tcode',how='left')

# %%
Imports_Tot.to_excel(f"{my_wd}/Data/Cleaned_Data/Y1403Imports.xlsx", index=False)
Exports_Tot.to_excel(f"{my_wd}/Data/Cleaned_Data/Y1403Exports.xlsx", index=False)

# %%
Imports_Tot
# Out:
#        Year                      Custom  Country       Tcode   Weight  \
# 0      1403                        اراک  اسلواکي  98843320.0    996.0
# 1      1403                        اراک    آلمان  38101029.0   7660.0
# 2      1403                        اراک    آلمان  38123910.0  50000.0
# 3      1403                        اراک    آلمان  39173100.0   1451.0
# 4      1403                        اراک    آلمان  39191090.0   3540.0
# ...     ...                         ...      ...         ...      ...
# 89145  1403  منطقه ويژه اقتصادي سلفچگان    ترکيه  76061290.0    405.0
# 89146  1403  منطقه ويژه اقتصادي سلفچگان    ترکيه  84145920.0   6520.0
# 89147  1403  منطقه ويژه اقتصادي سلفچگان    ترکيه  84248910.0    864.0
# 89148  1403  منطقه ويژه اقتصادي سلفچگان    ترکيه  90318050.0     67.0
# 89149  1403  منطقه ويژه اقتصادي سلفچگان   تايوان  35069190.0  17150.0
#
#               Rials   Dollars  Month  \
# 0      6.727771e+09   23606.0      6
# 1      5.884215e+09   20646.0      6
# ...
