# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# 29309990 has changed to 29309090

# %% [markdown]
# Check it all the times

# %%
Data = pd.read_excel(f'C:/TradeGroup/Reports/Tamin_Kalaee_Mahramane_DeletedIDs_6mahe1403.xlsx')
Data_Details = pd.read_excel(f'C:/TradeGroup/Data/Dashboard/HSs_complete_Final31.xlsx')


Data_Details
# Out:
#          HS6                                              HS6_E  \
# 0      10110  Live horses/asses/mules/hinnies: pure-bred bre...
# 1      10111                    Horses, live pure-bred breeding
# 2      10119             Horses, live except pure-bred breeding
# 3      10120                     Asses, mules and hinnies, live
# 4      10121                Horses : Pure-bred breeding animals
# ...      ...                                                ...
# 6795  999602                   Advance freight for export goods
# 6796  999700                            Registration of service
# 6797  999701  Registration of service of other foreign excha...
# 6798  999999       Commodities not specified, according to kind
# 6799  999999       Commodities not specified, according to kind
#
#                                                   HS6_F     HS4   HS2  \
# 0     اسب زنده / الاغ / قاطر / مرغ مرغ زنده: حیوانات...   101.0   1.0
# ...

# %%
Data['HS6'] = Data['HS8']//100
Detailed_Data = Data.merge(Data_Details,on='HS6',how='left')

Detailed_Data.to_excel(f'C:/TradeGroup/Data/Indices/Tamin_Arz_Mahramaneh_Dashboard_6mahe1403.xlsx',index=False)
