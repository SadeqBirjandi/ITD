# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir("C:\TradeGroup")
my_wd = os.getcwd()
new_directory = my_wd

# %%
World_Importers_Gross = pd.read_excel(f'C:/TradeGroup/Reports/Trade_Report/World_Importers.xlsx')

World_Importers = World_Importers_Gross[World_Importers_Gross['Importers']!="World"]
World_Imports = World_Importers_Gross[World_Importers_Gross['Importers']=="World"]
Importers_Columns = World_Importers.columns
World_Importers.fillna(0,inplace=True)
World_Imports
World_Ratios = World_Importers
World_Rankings = World_Importers
 
for my_col in Importers_Columns[1:]:
    World_Ratios[my_col] = World_Ratios[my_col]/World_Ratios[my_col].sum()
    
World_Ratios
# Out:
# C:\Users\msbirjandi\AppData\Local\Temp\ipykernel_10000\999490405.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   World_Importers.fillna(0,inplace=True)
# C:\Users\msbirjandi\AppData\Local\Temp\ipykernel_10000\999490405.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   World_Ratios[my_col] = World_Ratios[my_col]/World_Ratios[my_col].sum()
#                        Importers  Imported value in 2012  \
# 1       United States of America            1.269327e-01
# 2                          China            9.885257e-02
# ...
