# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir("C:\TradeGroup")
my_wd = os.getcwd()
new_directory = my_wd

# %%
HS6s = pd.read_excel(f"C:/TradeGroup/Data/Dashboard/HS6_New.xlsx")
HS4s = pd.read_excel(f"C:/TradeGroup/Data/Dashboard/4HSs_Complete.xlsx")
# Out:
# c:\Users\msbirjandi\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
HS6s['HS4']=HS6s['HS6'].astype('str').str.slice(0,-2)
HS6s['HS2']=HS6s['HS6'].astype('str').str.slice(0,-4)

HS6s['HS6'] = pd.to_numeric(HS6s['HS6'], errors='coerce')
HS6s['HS4'] = pd.to_numeric(HS6s['HS4'], errors='coerce')
HS6s['HS2'] = pd.to_numeric(HS6s['HS2'], errors='coerce')


HS6s.drop_duplicates(subset=['HS6'], keep='first', inplace=True)

HS6s['HS5']=HS6s['HS6']//10

HS6s = HS6s.merge(HS4s,on='HS4', how='outer')

HS6s
# Out:
#            HS6                                              HS6_E  \
# 0      10110.0  Live horses/asses/mules/hinnies: pure-bred bre...
# 1      10111.0                    Horses, live pure-bred breeding
# 2      10119.0             Horses, live except pure-bred breeding
# 3      10120.0                     Asses, mules and hinnies, live
# 4      10121.0                Horses : Pure-bred breeding animals
# ...        ...                                                ...
# 6280  988427.0  K.D. parts used in the manufacture of lift-tru...
# 6281  988429.0  K.D. parts for manufacturing road building mac...
# 6282  988433.0  K.D. parts for manufacturing combines excludin...
# 6283  988701.0  K.D. parts for manufacturing agricultural trac...
# 6284  999999.0       Commodities not specified, according to kind
#
#                                                   HS6_F     HS4  HS2      HS5  \
# 0     اسب زنده / الاغ / قاطر / مرغ مرغ زنده: حیوانات...   101.0    1   1011.0
# ...

# %%
#HS6s.to_excel(f"C:/TradeGroup/Data/Dashboard/HSs_complete_new_V2.xlsx", index= False)

# %% [markdown]
# This code is the latest code. The excel file is edited manually so do not save on this

# %%
HS6s = pd.read_excel(f"C:/TradeGroup/Data/Dashboard/HSs_complete_new_V2.xlsx")
HS2s = pd.read_excel(f"C:/TradeGroup/Data/Dashboard/HSs_Harvard_New.xlsx")


HS2s = HS2s.drop(['HS4'],axis=1)

HS2s = HS2s.drop_duplicates(subset=['HS2'])

HSs_Complete = HS6s.merge(HS2s,on="HS2", how="outer")

HSs_Complete
# Out:
#          HS6                                              HS6_E  \
# 0      10110  Live horses/asses/mules/hinnies: pure-bred bre...
# 1      10111                    Horses, live pure-bred breeding
# 2      10119             Horses, live except pure-bred breeding
# 3      10120                     Asses, mules and hinnies, live
# 4      10121                Horses : Pure-bred breeding animals
# ...      ...                                                ...
# 6425  988702  K.D. parts for manufacture motor vehicles tran...
# 6426  988703  K.D parts for manufacturing motor vehicles cov...
# 6427  988711  Motorcycles especially for using in racing and...
# 6428  988712                  Knocked down parts to biuld abike
# 6429  999999       Commodities not specified, according to kind
#
#                                                   HS6_F   HS4  HS2    HS5  \
# 0     اسب زنده / الاغ / قاطر / مرغ مرغ زنده: حیوانات...   101    1   1011
# ...

# %%
HSs_Complete.to_excel(f"C:/TradeGroup/Data/Dashboard/HSs_complete_Final.xlsx", index= False)
